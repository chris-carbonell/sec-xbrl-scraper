# %% [markdown]
# # Overview

# %% [markdown]
# - after scraping, scrub the data

# %% [markdown]
# # Dependencies

# %%
# general
import pandas as pd

# %% [markdown]
# # Input

# %%
str_output_dir = "./output/example/"

# %%
df_us_gaap = pd.read_csv(str_output_dir + "us-gaap.csv")

# %%
df_dei = pd.read_csv(str_output_dir + "dei.csv")

# %%
# quick check
df_us_gaap.groupby(['CIK']).agg('count')
# Out:
#          Filing  Filing Date  Filing Link    tag   text  contextref  decimals  \
# CIK
# 789019    18751        18751        18751  18751  18713       18748     17225
# 1018724    9822         9822         9822   9822   9787        9822      9458
# 1652044    6733         6733         6733   6733   6720        6731      6590
#
#             id  unitref  xsi:nil  xmlns:xsi
# CIK
# 789019   16039    17261       38          6
# 1018724   8391     9489       35          0
# 1652044   6731     6602       13          0

# %% [markdown]
# # US GAAP Tags

# %% [markdown]
# I like this explanation of the XLRB in general:<br>
# https://www.codeproject.com/Articles/1227765/Parsing-XBRL-with-Python
#
# It also provides a fantastic list of all of the most important tags!

# %%
dict_tags = {
    'us-gaap:accountspayablecurrent': "Liabilities payable to vendors as of the balance sheet date",
    'us-gaap:accountsreceivablegross': "Amounts due from customers or clients",
    'us-gaap:accountsreceivablenet': "Amounts due from customers or clients, reduced to estimated realizable value",
    'us-gaap:accruedincometaxes': "Unpaid sum of known and estimated tax obligations",
    'us-gaap:accruedinsurancecurrent': "Obligations payable to insurance entities to mitigate loss",
    'us-gaap:assetmanagementcosts': "Aggregate costs related to asset management",
    'us-gaap:assets': "Total Assets",
    'us-gaap:assetscurrent': "Sum of all assets expected to be realized within year",
    'us-gaap:borrowedfunds': "Sum of all debt amounts",
    'us-gaap:cash': "Unrestricted cash available for operating needs",
    'us-gaap:commercialpaper': "Value of short-term borrowings using unsecured obligations issued by banks and corporations",
    'us-gaap:commonstocknoparvalue': "Issuance value per share of no-par value stock",
    'us-gaap:commonstocksharesissued': "Total number of common shares that have been sold or granted to shareholders",
    'us-gaap:commonstockvalue': "Aggregate par or stated value of issued common stock",
    'us-gaap:salariesandwages': "Expenditures for salaries other than officers",
    'us-gaap:convertibledebt': "Amount of debt that can be converted into another form of financial instrument, such as common stock",
    'us-gaap:costofgoodssold': "Aggregate costs related to goods sold during the period",
    'us-gaap:costofservices': "Total costs related to services rendered during the period",
    'us-gaap:costsandexpenses': "Total costs of sales and operating expenses for the period",
    'us-gaap:debtcurrent': "Sum of short-term debt and maturities of long-term debt",
    'us-gaap:deferredrevenue': "Cash or other assets that have not yet been realized",
    'us-gaap:depreciation': "Amount of expense related to the cost of tangible assets over the assets' useful lives",
    'us-gaap:directoperatingcosts': "Aggregate expenses directly related to operations",
    'us-gaap:dividends': "Equity impact of cash, stock, and dividends declared  for all securities during the period",
    'us-gaap:earningspersharebasic': "Net income (loss) for the period per share of common stock",
    'us-gaap:grossprofit': "Aggregate revenue minus the cost of goods/services sold and operating expenses",
    'us-gaap:intangibleassetscurrent': "Current portion of non-physical assets, excluding financial assets",
    'us-gaap:interestanddebtexpense': "Expenses related to interest and debt payments",
    'us-gaap:inventorygross': "Merchandise, goods, or supplies held for future sale or used int manufacturing or production",
    'us-gaap:land': "Real estate held for productive use, not held for sale",
    'us-gaap:liabilities': "Sum of all recognized liabilities",
    'us-gaap:liabilitiesandstockholdersequity': "Total of liabilities and stockholder's equity, including the portion of equity attributable to noncontrolling interests",
    'us-gaap:netincomeloss': "Portion of profit or loss for the period, net of income taxes",
    'us-gaap:profitloss': "Consolidated profit or loss for the period",
    'us-gaap:notespayable': "Aggregate amount of notes payable, with initial maturities beyond one year or the normal operating cycle",
    'us-gaap:officerscompensation': "Expenditures for salaries of officers",
    'us-gaap:operatingcycle': "Entity's operating cycle if less than 12 months",
    'us-gaap:operatingexpenses': "Recurring costs associated with normal operations except expenses included in the cost of sales or services",
    'us-gaap:preferredstockvalue': "Stated value of issued nonredeemable preferred stock",
    'us-gaap:researchanddevelopment': "Costs incurred during research and development ",
    'us-gaap:expense': "activities",
    'us-gaap:revenues': "Aggregate revenue recognized during the period",
    'us-gaap:sharesissued': "Number of shares of stock issued",
    'us-gaap:sharesoutstanding': "Number of shares issued and outstanding",
    'us-gaap:stockholdersequity': "Total of stockholders' equity items, net of receivables from officers, directors, owners, and affiliates"
}

# %% [markdown]
# # Scrub

# %% [markdown]
# Unfortunately, each company uses their own unique contexts!
#
# Assuming we'll be working with AMZN, GOOG, and MSFT often, I invested the manual work of mapping out the contexts for each company.
#
# See the notes below for more info.

# %%
def get_text(df, cik, tag, contextref, value = "text"):
    # multiples may exist depending on how it's used in the doc
    try:
        return df[(df['CIK'] == cik) & (df['tag'] == tag) & (df['contextref'] == contextref)].reset_index().iloc[0][value]
    except:
        return None

# %%
def get_ls_financials(df, cik, ls_context, ls_tags):
    ls_financials = []
    for tag in ls_tags:
        for contextref in ls_context:
            dict_financials = {
                'CIK': cik,
                'Filing Link': get_text(df, cik, tag, contextref, "Filing Link"),
                'tag': tag,
                'contextref': contextref,
                'text': get_text(df, cik, tag, contextref, "text")
            }
            ls_financials.append(dict_financials)

    return ls_financials

# %% [markdown]
# # AMZN

# %% [markdown]
# AMZN is consistent. Their contexts go FIYYYYQ4.

# %%
# # get df
# ls_financials = get_ls_financials(
#     df_us_gaap, 
#     1018724, 
#     ls_context = ["FI" + str(year) + "Q4" for year in range(2012,2020)], 
#     ls_tags = dict_tags.keys()
# )
# df_amzn_tidy = pd.DataFrame(ls_financials)
# # df_amzn_tidy

# %%
# # add FY
# df_amzn_tidy['FY'] = df_amzn_tidy['contextref'].str[2:6]
# df_amzn_tidy
# Out:
#          CIK                                        Filing Link  \
# 0    1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 1    1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 2    1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 3    1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 4    1018724  https://www.sec.gov/Archives/edgar/data/101872...
# ..       ...                                                ...
# 347  1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 348  1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 349  1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 350  1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 351  1018724  https://www.sec.gov/Archives/edgar/data/101872...
#
#                                 tag contextref         text    FY
# 0    us-gaap:accountspayablecurrent   FI2012Q4  13318000000  2012
# 1    us-gaap:accountspayablecurrent   FI2013Q4  15133000000  2013
# 2    us-gaap:accountspayablecurrent   FI2014Q4  16459000000  2014
# 3    us-gaap:accountspayablecurrent   FI2015Q4  20397000000  2015
# 4    us-gaap:accountspayablecurrent   FI2016Q4  25309000000  2016
# ..                              ...        ...          ...   ...
# 347      us-gaap:stockholdersequity   FI2015Q4  13384000000  2015
# 348      us-gaap:stockholdersequity   FI2016Q4  19285000000  2016
# 349      us-gaap:stockholdersequity   FI2017Q4  27709000000  2017
# 350      us-gaap:stockholdersequity   FI2018Q4  43549000000  2018
# 351      us-gaap:stockholdersequity   FI2019Q4  62060000000  2019
#
# [352 rows x 6 columns]

# %%
df_amzn_tidy = df_us_gaap[(df_us_gaap['CIK'] == 1018724)][['CIK','Filing Link', 'tag', 'contextref', 'text']]
# df_amzn_tidy['FY'] = df_amzn_tidy['contextref'].str[2:6]
df_amzn_tidy
# Out:
#           CIK                                        Filing Link  \
# 0     1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 1     1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 2     1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 3     1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 4     1018724  https://www.sec.gov/Archives/edgar/data/101872...
# ...       ...                                                ...
# 9817  1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 9818  1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 9819  1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 9820  1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 9821  1018724  https://www.sec.gov/Archives/edgar/data/101872...
#
#                                                     tag  \
# 0           us-gaap:commonstockparorstatedvaluepershare
# 1           us-gaap:commonstockparorstatedvaluepershare
# 2                   us-gaap:commonstocksharesauthorized
# 3                   us-gaap:commonstocksharesauthorized
# 4                       us-gaap:commonstocksharesissued
# ...                                                 ...
# 9817  us-gaap:stockissuedduringperiodvaluestockoptio...
# 9818  us-gaap:stockissuedduringperiodsharesstockopti...
# 9819         us-gaap:stockrepurchasedduringperiodshares
# 9820                              us-gaap:netincomeloss
# 9821          us-gaap:stockrepurchasedduringperiodvalue
#
#                                              contextref        text
# 0                                              FI2018Q4        0.01
# 1                                              FI2019Q4        0.01
# 2                                              FI2018Q4  5000000000
# 3                                              FI2019Q4  5000000000
# 4                                              FI2018Q4   514000000
# ...                                                 ...         ...
# 9817  eol_PE7235----0910-K0010_STD_366_20081231_0_41...   624000000
# 9818  eol_PE7235----0910-K0010_STD_366_20081231_0_41...    14000000
# 9819  eol_PE7235----0910-K0010_STD_366_20081231_0_41...    -2000000
# 9820  eol_PE7235----0910-K0010_STD_366_20081231_0_41...   645000000
# 9821  eol_PE7235----0910-K0010_STD_366_20081231_0_41...   100000000
#
# [9822 rows x 5 columns]

# %% [markdown]
# # GOOG

# %% [markdown]
# GOOG uses the same contexts as AMZN!

# %%
# # get df
# ls_financials = get_ls_financials(
#     df_us_gaap, 
#     1652044, 
#     ls_context = ["FI" + str(year) + "Q4" for year in range(2012,2020)], 
#     ls_tags = dict_tags.keys()
# )
# df_goog_tidy = pd.DataFrame(ls_financials)
# # df_goog_tidy

# %%
# # add FY
# df_goog_tidy['FY'] = df_goog_tidy['contextref'].str[2:6]

# %%
df_goog_tidy = df_us_gaap[(df_us_gaap['CIK'] == 1652044)][['CIK','Filing Link', 'tag', 'contextref', 'text']]
df_goog_tidy
# Out:
#            CIK                                        Filing Link  \
# 9822   1652044  https://www.sec.gov/Archives/edgar/data/165204...
# 9823   1652044  https://www.sec.gov/Archives/edgar/data/165204...
# 9824   1652044  https://www.sec.gov/Archives/edgar/data/165204...
# 9825   1652044  https://www.sec.gov/Archives/edgar/data/165204...
# 9826   1652044  https://www.sec.gov/Archives/edgar/data/165204...
# ...        ...                                                ...
# 16550  1652044  https://www.sec.gov/Archives/edgar/data/165204...
# 16551  1652044  https://www.sec.gov/Archives/edgar/data/165204...
# 16552  1652044  https://www.sec.gov/Archives/edgar/data/165204...
# 16553  1652044  https://www.sec.gov/Archives/edgar/data/165204...
# 16554  1652044  https://www.sec.gov/Archives/edgar/data/165204...
#
#                                                      tag   contextref  \
# 9822   us-gaap:revenueremainingperformanceobligatione...          NaN
# 9823   us-gaap:revenueremainingperformanceobligatione...          NaN
# 9824   us-gaap:allowancefordoubtfulaccountsreceivable...     FI2018Q4
# 9825   us-gaap:allowancefordoubtfulaccountsreceivable...     FI2019Q4
# 9826                             us-gaap:commercialpaper     FI2018Q4
# ...                                                  ...          ...
# 16550      us-gaap:fairvalueoffinancialinstrumentspolicy  FD2015Q4YTD
# 16551  us-gaap:priorperiodreclassificationadjustmentd...  FD2015Q4YTD
# 16552             us-gaap:scheduleofrepurchaseagreements  FD2015Q4YTD
# 16553  us-gaap:sharebasedcompensationoptionandincenti...  FD2015Q4YTD
# 16554                             us-gaap:useofestimates  FD2015Q4YTD
#
#                                                     text
# 9822                                          2020-01-01
# 9823                                          2022-01-01
# 9824                                           729000000
# 9825                                           753000000
# 9826                                                   0
# ...                                                  ...
# 16550  <div style="font-family:Times New Roman;font-s...
# 16551  <div style="font-family:Times New Roman;font-s...
# 16552  <div style="font-family:Times New Roman;font-s...
# 16553  <div style="font-family:Times New Roman;font-s...
# 16554  <div style="font-family:Times New Roman;font-s...
#
# [6733 rows x 5 columns]

# %% [markdown]
# # MSFT

# %% [markdown]
# MSFT has an organized set of contexts too but different from AMZN and GOOG.
#
# MSFT also uses a different fiscal calendar ending 6/30.

# %%
# # get df
# ls_financials = get_ls_financials(
#     df_us_gaap, 
#     789019, 
#     ls_context = ["C_0000789019_" + str(year) + "0630" for year in range(2012,2021)], 
#     ls_tags = dict_tags.keys()
# )
# df_msft_tidy = pd.DataFrame(ls_financials)
# # df_msft_tidy

# %%
# # add FY
# df_msft_tidy['FY'] = df_msft_tidy['contextref'].str[13:17]

# %%
df_msft_tidy = df_us_gaap[(df_us_gaap['CIK'] == 789019)][['CIK','Filing Link', 'tag', 'contextref', 'text']]
df_msft_tidy
# Out:
#           CIK                                        Filing Link  \
# 16555  789019  https://www.sec.gov/Archives/edgar/data/789019...
# 16556  789019  https://www.sec.gov/Archives/edgar/data/789019...
# 16557  789019  https://www.sec.gov/Archives/edgar/data/789019...
# 16558  789019  https://www.sec.gov/Archives/edgar/data/789019...
# 16559  789019  https://www.sec.gov/Archives/edgar/data/789019...
# ...       ...                                                ...
# 35301  789019  https://www.sec.gov/Archives/edgar/data/789019...
# 35302  789019  https://www.sec.gov/Archives/edgar/data/789019...
# 35303  789019  https://www.sec.gov/Archives/edgar/data/789019...
# 35304  789019  https://www.sec.gov/Archives/edgar/data/789019...
# 35305  789019  https://www.sec.gov/Archives/edgar/data/789019...
#
#                                                      tag  \
# 16555  us-gaap:revenueremainingperformanceobligatione...
# 16556    us-gaap:accountingstandardsupdateextensiblelist
# 16557    us-gaap:accountingstandardsupdateextensiblelist
# 16558    us-gaap:accountingstandardsupdateextensiblelist
# 16559    us-gaap:accountingstandardsupdateextensiblelist
# ...                                                  ...
# 35301                              us-gaap:netincomeloss
# 35302             us-gaap:paymentsofdividendscommonstock
# 35303                                   us-gaap:revenues
# 35304         us-gaap:stockrepurchasedduringperiodshares
# 35305          us-gaap:stockrepurchasedduringperiodvalue
#
#                                        contextref  \
# 16555                                         NaN
# 16556              C_0000789019_20190701_20200630
# 16557              C_0000789019_20180701_20190630
# 16558              C_0000789019_20170701_20180630
# 16559              C_0000789019_20190701_20200630
# ...                                           ...
# 35301  eol_PE8528----1010-K0014_STD_92_20091231_0
# 35302  eol_PE8528----1010-K0014_STD_92_20091231_0
# 35303  eol_PE8528----1010-K0014_STD_92_20091231_0
# 35304  eol_PE8528----1010-K0014_STD_92_20091231_0
# 35305  eol_PE8528----1010-K0014_STD_92_20091231_0
#
#                                                 text
# 16555                                     2020-07-01
# 16556  us-gaap:AccountingStandardsUpdate201601Member
# 16557  us-gaap:AccountingStandardsUpdate201601Member
# 16558  us-gaap:AccountingStandardsUpdate201601Member
# 16559  us-gaap:AccountingStandardsUpdate201601Member
# ...                                              ...
# 35301                                     6662000000
# 35302                                     1139000000
# 35303                                    19022000000
# 35304                                      125000000
# 35305                                     3583000000
#
# [18751 rows x 5 columns]

# %% [markdown]
# # Combine & Final Cleanup

# %% [markdown]
# ## Combine

# %%
# combine
df_stacked_financials = pd.concat([df_amzn_tidy, df_goog_tidy, df_msft_tidy], axis = 0, ignore_index = True)
df_stacked_financials
# Out:
#            CIK                                        Filing Link  \
# 0      1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 1      1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 2      1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 3      1018724  https://www.sec.gov/Archives/edgar/data/101872...
# 4      1018724  https://www.sec.gov/Archives/edgar/data/101872...
# ...        ...                                                ...
# 35301   789019  https://www.sec.gov/Archives/edgar/data/789019...
# 35302   789019  https://www.sec.gov/Archives/edgar/data/789019...
# 35303   789019  https://www.sec.gov/Archives/edgar/data/789019...
# 35304   789019  https://www.sec.gov/Archives/edgar/data/789019...
# 35305   789019  https://www.sec.gov/Archives/edgar/data/789019...
#
#                                                tag  \
# 0      us-gaap:commonstockparorstatedvaluepershare
# 1      us-gaap:commonstockparorstatedvaluepershare
# 2              us-gaap:commonstocksharesauthorized
# 3              us-gaap:commonstocksharesauthorized
# 4                  us-gaap:commonstocksharesissued
# ...                                            ...
# 35301                        us-gaap:netincomeloss
# 35302       us-gaap:paymentsofdividendscommonstock
# 35303                             us-gaap:revenues
# 35304   us-gaap:stockrepurchasedduringperiodshares
# 35305    us-gaap:stockrepurchasedduringperiodvalue
#
#                                        contextref         text
# 0                                        FI2018Q4         0.01
# 1                                        FI2019Q4         0.01
# 2                                        FI2018Q4   5000000000
# 3                                        FI2019Q4   5000000000
# 4                                        FI2018Q4    514000000
# ...                                           ...          ...
# 35301  eol_PE8528----1010-K0014_STD_92_20091231_0   6662000000
# 35302  eol_PE8528----1010-K0014_STD_92_20091231_0   1139000000
# 35303  eol_PE8528----1010-K0014_STD_92_20091231_0  19022000000
# 35304  eol_PE8528----1010-K0014_STD_92_20091231_0    125000000
# 35305  eol_PE8528----1010-K0014_STD_92_20091231_0   3583000000
#
# [35306 rows x 5 columns]

# %% [markdown]
# ## Join on DEI Details

# %%
def get_dei_detail(df_dei, filing_link, tag, value = "text"):
    try:
        return df_dei[
            (df_dei['Filing Link'] == filing_link) &
            (df_dei['tag'] == tag)
        ].reset_index().iloc[0][value]
    except:
        return None

# %%
ls_dei_tags = [
    "dei:entityregistrantname",
    "dei:tradingsymbol",
    "dei:documentfiscalyearfocus",
    "dei:documentperiodenddate"
]

# %%
# get details for all filings
ls_dei_details = []
for filing_link in df_dei['Filing Link'].unique().tolist():
    dict_details = {'Filing Link': filing_link}
    for die_tag in ls_dei_tags:
        dict_details[die_tag[4:]] = get_dei_detail(
            df_dei = df_dei,
            filing_link = filing_link,
            tag = die_tag
        )
    ls_dei_details.append(dict_details)

# %%
df_dei_details = pd.DataFrame(ls_dei_details)
df_dei_details
# Out:
#                                           Filing Link   entityregistrantname  \
# 0   https://www.sec.gov/Archives/edgar/data/101872...       AMAZON.COM, INC.
# 1   https://www.sec.gov/Archives/edgar/data/101872...         AMAZON COM INC
# 2   https://www.sec.gov/Archives/edgar/data/101872...         AMAZON COM INC
# 3   https://www.sec.gov/Archives/edgar/data/101872...         AMAZON COM INC
# 4   https://www.sec.gov/Archives/edgar/data/101872...         AMAZON COM INC
# 5   https://www.sec.gov/Archives/edgar/data/101872...         AMAZON COM INC
# 6   https://www.sec.gov/Archives/edgar/data/101872...         AMAZON COM INC
# 7   https://www.sec.gov/Archives/edgar/data/101872...         AMAZON COM INC
# 8   https://www.sec.gov/Archives/edgar/data/101872...         AMAZON COM INC
# 9   https://www.sec.gov/Archives/edgar/data/101872...         AMAZON COM INC
# 10  https://www.sec.gov/Archives/edgar/data/101872...        AMAZON COM INC
# 11  https://www.sec.gov/Archives/edgar/data/165204...          Alphabet Inc.
# 12  https://www.sec.gov/Archives/edgar/data/165204...          Alphabet Inc.
# 13  https://www.sec.gov/Archives/edgar/data/165204...          Alphabet Inc.
# 14  https://www.sec.gov/Archives/edgar/data/165204...          Alphabet Inc.
# 15  https://www.sec.gov/Archives/edgar/data/165204...          Alphabet Inc.
# 16  https://www.sec.gov/Archives/edgar/data/789019...  MICROSOFT CORPORATION
# 17  https://www.sec.gov/Archives/edgar/data/789019...  MICROSOFT CORPORATION
# 18  https://www.sec.gov/Archives/edgar/data/789019...  MICROSOFT CORPORATION
# 19  https://www.sec.gov/Archives/edgar/data/789019...  MICROSOFT CORPORATION
# 20  https://www.sec.gov/Archives/edgar/data/789019...  MICROSOFT CORPORATION
# 21  https://www.sec.gov/Archives/edgar/data/789019...  MICROSOFT CORPORATION
# 22  https://www.sec.gov/Archives/edgar/data/789019...  MICROSOFT CORPORATION
# 23  https://www.sec.gov/Archives/edgar/data/789019...  MICROSOFT CORPORATION
# 24  https://www.sec.gov/Archives/edgar/data/789019...         MICROSOFT CORP
# 25  https://www.sec.gov/Archives/edgar/data/789019...         MICROSOFT CORP
# 26  https://www.sec.gov/Archives/edgar/data/789019...         MICROSOFT CORP
#
#    tradingsymbol documentfiscalyearfocus documentperiodenddate
# 0           AMZN                    2019            2019-12-31
# 1           None                    2018            2018-12-31
# 2           None                    2017            2017-12-31
# 3           AMZN                    2016            2016-12-31
# 4           AMZN                    2015            2015-12-31
# 5           AMZN                    2014            2014-12-31
# 6           AMZN                    2013            2013-12-31
# 7           AMZN                    2012            2012-12-31
# 8           AMZN                    2011            2011-12-31
# 9           AMZN                    2010            2010-12-31
# 10          AMZN                    None            2009-12-31
# 11         GOOGL                    2019            2019-12-31
# 12   GOOG, GOOGL                    2018            2018-12-31
# 13   GOOG, GOOGL                    2017            2017-12-31
# 14   GOOG, GOOGL                    2016            2016-12-31
# 15   GOOG, GOOGL                    2015            2015-12-31
# 16          MSFT                    2020            2020-06-30
# 17          MSFT                    2019            2019-06-30
# 18          MSFT                    2018            2018-06-30
# 19          MSFT                    2017            2017-06-30
# 20          MSFT                    2016            2016-06-30
# 21          MSFT                    2015            2015-06-30
# 22          MSFT                    2014            2014-06-30
# 23          MSFT                    2013            2013-06-30
# 24          MSFT                    2012            2012-06-30
# 25          MSFT                    2011            2011-06-30
# 26          MSFT                    2010            2010-06-30

# %%
df_final = pd.merge(df_stacked_financials, df_dei_details, on = 'Filing Link')

# %%
# df_final['tag_def'] = df_final.apply(lambda x: dict_tags[x['tag']], axis = 1)

# %%
df_final.to_excel(str_output_dir + "df_final.xlsx", "df_final", index = False, freeze_panes = (1,1))

# %% [markdown]
# # Testing

# %%
len(df_us_gaap.index)
# Out:
# 35306

# %%
len(df_dei_details.index)
# Out:
# 27

# %%
len(df_amzn_tidy.index)
# Out:
# 9822

# %%
len(df_stacked_financials.index)
# Out:
# 35306

# %%
len(df_final.index)
# Out:
# 35306

# %%
# testing
int_index = 0
print(df_final.iloc[int_index]['Filing Link'])
df_final.iloc[int_index]
# Out:
# https://www.sec.gov/Archives/edgar/data/1018724/000101872414000006/0001018724-14-000006-index.htm
# CIK                                                                  1018724
# Filing Link                https://www.sec.gov/Archives/edgar/data/101872...
# tag                                           us-gaap:accountspayablecurrent
# contextref                                                          FI2012Q4
# text                                                             13318000000
# FY                                                                      2012
# entityregistrantname                                          AMAZON COM INC
# tradingsymbol                                                           AMZN
# documentfiscalyearfocus                                                 2013
# documentperiodenddate                                             2013-12-31
# tag_def                    Liabilities payable to vendors as of the balan...
# Name: 0, dtype: object
